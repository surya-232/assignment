# %% [markdown]
# # ##Q.1 - Create a dataframe with your name , age , mail id and phone number and add your friends’s information to the same.

# %%
import pandas as p
import numpy as np

d = {
    'name' : ['surya','ashwani','charu','shivam','karna'],
    'age' : [19,20,20,21,21],
    'mail_id' : ['saxenasurya001@gmail.com','ashwani6969@gmail.com','charuvashist@gmail.com','sainikalaunda@gmail.com','abikarna@gmail.com'],
    'ph_number' : [9053408984,9053408998,9053408984,9053408984,9999999999]
}
df=p.DataFrame(d)
print(df)
# Out:
#       name  age                   mail_id   ph_number
# 0    surya   19  saxenasurya001@gmail.com  9053408984
# 1  ashwani   20     ashwani6969@gmail.com  9053408998
# 2    charu   20    charuvashist@gmail.com  9053408984
# 3   shivam   21   sainikalaunda@gmail.com  9053408984
# 4    karna   21        abikarna@gmail.com  9999999999

# %% [markdown]
# # ##Import the data and print the following :a.) First 5 rows of Dataframe b.) First 10 rows of the Dataframec.) find basic statistics on the particular dataset. d.) Find the last 5 rows of the dataframe e.) Extract the 2nd column and find basic statistics on it.

# %%
import pandas as p
import numpy as np
df=p.read_csv('s.csv')
print(df)
print(df.head(5))
print(df[0:5])
print(df.head(10))
print(df.describe())
print(df.tail(5))
print(df['Location'].describe())
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1     11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2     11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3     11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4     11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
# 5     11/6/2007  Canberra      6.2     16.9       0.0          5.8       8.2
# 6     11/7/2007  Canberra      6.1     18.2       0.2          4.2       8.4
# 7     11/8/2007  Canberra      8.3     17.0       0.0          5.6       4.6
# 8     11/9/2007  Canberra      8.8     19.5       0.0          4.0       4.1
# 9    11/10/2007  Canberra      8.4     22.8      16.2          5.4       7.7
# 10   11/11/2007  Canberra      9.1     25.2       0.0          4.2      11.9
# ...

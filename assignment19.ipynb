# %% [markdown]
# # #Question.1 Create a numpy array with 10 elements of the shape(10,1) using np.random and find out the mean of the elements using basic

# %%
import numpy as np
a=np.random.random([10,1])
print(a)
print(a.mean())
# Out:
# [[0.400634  ]
#  [0.3510398 ]
#  [0.51070871]
#  [0.07576318]
#  [0.30150888]
#  [0.92172638]
#  [0.68099951]
#  [0.79118545]
#  [0.4871208 ]
#  [0.38809065]]
# 0.4908777360865598

# %% [markdown]
# # Question.2 Create a numpy array with 20 elements of the shape(20,1) using np.random find the variance and standard deviation of the elements

# %%
import numpy as np
x=np.random.random([20,1])
print(x)
print(x.var())
print(x.std())
# Out:
# [[0.85906036]
#  [0.40133476]
#  [0.97755322]
#  [0.07628184]
#  [0.72726821]
#  [0.16285727]
#  [0.56652212]
#  [0.49340544]
#  [0.59090981]
#  [0.75906076]
#  [0.79417504]
#  [0.62447341]
#  [0.29362985]
#  [0.15901693]
#  [0.1706805 ]
#  [0.97511514]
#  [0.00504009]
#  [0.62997257]
#  [0.75566851]
#  [0.16644694]]
# 0.09116088297277528
# 0.30192860575436586

# %% [markdown]
# # Question.3 Create a numpy array A of shape(10,20) and B of shape (20,25) using np.random. Print the matrix which is the matrix multiplication of A and B. The shape of the new matrix should be (10,25). Using basic numpy math functions only find the sum of all the elements of the new matrix

# %%
import numpy as np
a=np.random.random([10,20])
b=np.random.random([20,25])
print(np.matmul(a,b))
# Out:
# [[5.00344313 6.55700684 4.21560648 4.51489392 6.44147434 6.15919984
#   6.32218016 5.57855237 5.27652831 4.08630916 5.74330105 5.77758841
#   6.1170045  6.06150458 5.83358606 6.07055316 4.80857617 6.11690229
#   4.30457186 5.24694484 5.86411942 5.84109407 4.58931372 4.68403593
#   5.67133129]
#  [3.82316798 5.55261018 2.73508085 2.87479906 4.12114836 3.92530711
#   3.62486438 4.77974115 2.82962105 3.0325738  3.55153244 3.57759836
#   3.83579491 4.44684822 4.37228281 3.86063129 3.39303213 3.73137282
#   3.28917004 3.85956859 4.11619282 4.77343845 2.82306232 3.48451323
#   4.97400487]
#  [4.52726005 6.93760547 3.7630017  4.32533372 6.67545138 5.61855123
#   5.38131413 6.26923223 4.76088219 4.31077105 5.42858695 5.51319034
#   5.79891184 6.00223854 5.93695506 5.22360897 4.76303776 5.71783003
#   4.43056896 5.29702023 4.97373979 6.3331456  3.8044415  4.82941086
#   5.77942542]
#  [3.64964098 6.32731322 3.32140483 3.92784995 4.38755672 5.03352361
#   4.75612232 4.68899369 3.51553681 3.58563123 4.22418419 4.03239336
#   5.5258747  5.72865764 5.0158748  4.39639547 3.61552695 4.95641043
#   4.76352981 3.6121651  5.07665873 5.60288676 3.97307857 3.71973624
#   4.9289515 ]
#  [4.2487937  5.85387649 4.18232281 5.19647049 6.451146   5.07646384
#   5.06089573 5.42690076 4.66519252 3.80972308 4.82408777 5.43064589
#   5.71928855 5.35683549 5.4056233  5.07133728 4.34115837 5.44457201
#   5.63342553 5.16542568 5.24509315 5.54063945 4.41839232 4.22252923
#   5.61265678]
#  [4.87170181 6.44812951 3.96294634 4.51147959 5.56480478 5.08959589
#   6.16351461 4.96886465 4.82507424 3.80852014 5.87569339 5.0888126
#   5.26520378 5.96731345 5.22675748 5.76722122 3.78237423 5.92530056
#   4.92872242 4.50889572 5.48083503 5.72035712 4.56544794 3.99232206
#   5.7867891 ]
#  [4.10501135 6.05269118 3.70717342 4.6841254  4.76141445 5.03486197
#   4.27084789 4.61906032 4.73673761 3.37921801 4.49128467 3.79078253
#   4.85292435 4.47088874 4.30557227 4.81609006 4.30469852 5.29263735
#   4.40279305 4.18048997 4.82166836 4.74224922 3.14829559 3.95614697
#   4.77382839]
#  [5.03441474 7.36012577 3.80084691 4.82448412 6.00179486 5.58037902
#   5.32627446 5.15094808 4.85960369 4.4958513  4.60889616 4.70938581
#   6.02986931 5.5395312  5.85785609 5.13172339 5.25411383 5.51726217
#   4.90366255 4.91466209 5.56979311 5.94759778 3.91611108 4.68061638
#   5.42992414]
#  [3.96003155 5.92034101 3.7240961  3.96121811 5.26521139 5.12865818
#   4.37123279 5.12508015 4.33144459 3.05098297 4.25852753 5.09751193
#   5.15183321 4.73037632 5.04813621 4.83950027 3.82172601 4.82295178
#   4.64249483 4.76648861 4.63916376 5.08862262 3.80364755 4.24985663
#   5.38581449]
#  [5.54065687 7.87950985 4.21501114 5.15457952 5.9832022  6.54344567
#   5.86078696 6.4000097  5.23221199 4.23871196 5.89536966 6.32268753
#   5.96274221 6.36780254 6.404142   5.87773957 4.3944976  6.20802092
#   5.86881212 5.59008963 5.6363725  6.52287116 4.89625418 5.12074707
#   5.8950081 ]]

# %% [markdown]
# # Question.4 Create a numpy array A of shape(10,1).Using the basic operations of the numpy array generate an array of shape(10,1) such that each element is the following function applied on each element of A

# %%
import numpy as np
A=np.random.random((10,1))
print(A)
def func(x):
      return (1/(1+np.exp(-x)))
result = np.apply_along_axis(func , 0 , A)
print(result)
# Out:
# [[0.5235029 ]
#  [0.29889818]
#  [0.10294655]
#  [0.62585097]
#  [0.6396338 ]
#  [0.90266159]
#  [0.41601718]
#  [0.04633136]
#  [0.69207523]
#  [0.11449488]]
# [[0.6279665 ]
#  [0.57417315]
#  [0.52571393]
#  [0.65154809]
#  [0.65467067]
#  [0.71149615]
#  [0.6025298 ]
#  [0.51158077]
#  [0.66642841]
#  [0.52859249]]
